# %% [markdown]
# <a href="https://colab.research.google.com/github/Tuhin092005/Machine-Learning-Algorithms/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 2
b = 3

sum = a + b

print(sum)
# Out:
# 5
